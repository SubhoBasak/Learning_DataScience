# %% [markdown]
# # **LAB FEEDBACK(2019 3rd Semester)**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('2019 ODD SEM 3RD SEM CSE LAB FEEDBACK .csv')

# %%
titles=list(df.columns)

# %%
titles
# Out:
# ['Timestamp',
#  'NAME OF STUDENT',
#  '1)Instructor’s knowledge about the subject [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SNB]',
#  '1)Instructor’s knowledge about the subject [Analog & Digital ElectronicS Lab(ESC 301)-AN]',
#  '1)Instructor’s knowledge about the subject [Analog & Digital ElectronicS Lab(ESC 301)-DB]',
#  '1)Instructor’s knowledge about the subject [Data Structure & Algorithms Lab(PCC-CS301)-SYG]',
#  '1)Instructor’s knowledge about the subject [Data Structure & Algorithms Lab (PCC-CS301)-AGB]',
#  '1)Instructor’s knowledge about the subject [Computer Organisation Lab(PCC-CS302)-RPC]',
#  '1)Instructor’s knowledge about the subject [Computer Organisation Lab(PCC-CS302)-SBK]',
#  '1)Instructor’s knowledge about the subject [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SB]',
#  "2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SNB]",
# ...

# %%
titles.remove('Timestamp')
titles.remove('NAME OF STUDENT')

# %%
df.shape
# Out:
# (42, 58)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 58 columns):
# Timestamp                                                                                                                                              42 non-null object
# NAME OF STUDENT                                                                                                                                        42 non-null object
# 1)Instructor’s knowledge about the subject [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SNB]                                                      42 non-null object
# 1)Instructor’s knowledge about the subject [Analog & Digital ElectronicS Lab(ESC 301)-AN]                                                              42 non-null object
# 1)Instructor’s knowledge about the subject [Analog & Digital ElectronicS Lab(ESC 301)-DB]                                                              42 non-null object
# ...

# %% [markdown]
# # **EDA**

# %%
def analysis(title):
  print('Analysis on '+title)
  print('\n')
  print(df[title].value_counts(normalize=True)*100)
  print('\n')
  df[title].value_counts(normalize=True).plot.bar(title=title)
  plt.show()
  print('\n')

# %% [markdown]
# ## **IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SNB**

# %%
index=0
for ind,val in enumerate(titles):
    if ind == 0:
      analysis(titles[index])
    elif index < len(code)-8:
      index=index+8
      analysis(titles[index])
# Out:
# Analysis on 1)Instructor’s knowledge about the subject [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SNB]
#
#
# Excellent    85.714286
# Very Good    11.904762
# Good          2.380952
# Name: 1)Instructor’s knowledge about the subject [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SNB], dtype: float64
# Analysis on 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SNB]
#
#
# Excellent    88.095238
# Very Good     9.523810
# Good          2.380952
# Name: 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SNB], dtype: float64
# Analysis on 3)Adequacy of time allotted for each experiment of the Course. [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SNB]
#
#
# Excellent    88.095238
# Very Good     9.523810
# Good          2.380952
# ...

# %% [markdown]
# ## **IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SB**

# %%
index=7
for ind,val in enumerate(titles):
    if ind == 0:
      analysis(titles[index])
    elif index < len(code)-8:
      index=index+8
      analysis(titles[index])
# Out:
# Analysis on 1)Instructor’s knowledge about the subject [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SB]
#
#
# Excellent    78.571429
# Very Good    16.666667
# Good          4.761905
# Name: 1)Instructor’s knowledge about the subject [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SB], dtype: float64
# Analysis on 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SB]
#
#
# Excellent    78.571429
# Very Good    14.285714
# Good          4.761905
# Poor          2.380952
# Name: 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SB], dtype: float64
# Analysis on 3)Adequacy of time allotted for each experiment of the Course. [IT Workshop (SciLab/MATLAB/Python/R)(PCC-CS393) -SB]
#
#
# Excellent    73.809524
# Very Good    19.047619
# Good          7.142857
# ...

# %% [markdown]
# ## **Analog & Digital ElectronicS Lab(ESC 301)-AN**

# %%
index=1
for ind,val in enumerate(titles):
    if ind == 0:
      analysis(titles[index])
    elif index < len(code)-8:
      index=index+8
      analysis(titles[index])
# Out:
# Analysis on 1)Instructor’s knowledge about the subject [Analog & Digital ElectronicS Lab(ESC 301)-AN]
#
#
# Excellent    73.809524
# Very Good    19.047619
# Good          7.142857
# Name: 1)Instructor’s knowledge about the subject [Analog & Digital ElectronicS Lab(ESC 301)-AN], dtype: float64
# Analysis on 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Analog & Digital ElectronicS Lab(ESC 301)-AN]
#
#
# Excellent    73.809524
# Very Good    21.428571
# Good          4.761905
# Name: 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Analog & Digital ElectronicS Lab(ESC 301)-AN], dtype: float64
# Analysis on 3)Adequacy of time allotted for each experiment of the Course. [Analog & Digital ElectronicS Lab(ESC 301)-AN]
#
#
# Excellent    69.047619
# Very Good    21.428571
# Good          7.142857
# Poor          2.380952
# ...

# %% [markdown]
# ## **Analog & Digital ElectronicS Lab(ESC 301)-DB**

# %%
index=2
for ind,val in enumerate(titles):
    if ind == 0:
      analysis(titles[index])
    elif index < len(code)-8:
      index=index+8
      analysis(titles[index])
# Out:
# Analysis on 1)Instructor’s knowledge about the subject [Analog & Digital ElectronicS Lab(ESC 301)-DB]
#
#
# Excellent    47.619048
# Very Poor    21.428571
# Good         14.285714
# Poor          9.523810
# Very Good     7.142857
# Name: 1)Instructor’s knowledge about the subject [Analog & Digital ElectronicS Lab(ESC 301)-DB], dtype: float64
# Analysis on 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Analog & Digital ElectronicS Lab(ESC 301)-DB]
#
#
# Excellent    42.857143
# Very Poor    23.809524
# Very Good    16.666667
# Good          9.523810
# Poor          7.142857
# Name: 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Analog & Digital ElectronicS Lab(ESC 301)-DB], dtype: float64
# Analysis on 3)Adequacy of time allotted for each experiment of the Course. [Analog & Digital ElectronicS Lab(ESC 301)-DB]
#
#
# Excellent    52.380952
# Very Good    19.047619
# Very Poor    16.666667
# Poor          7.142857
# ...

# %% [markdown]
# ## **Data Structure & Algorithms Lab(PCC-CS301)-SYG**

# %%
index=3
for ind,val in enumerate(titles):
    if ind == 0:
      analysis(titles[index])
    elif index < len(code)-8:
      index=index+8
      analysis(titles[index])
# Out:
# Analysis on 1)Instructor’s knowledge about the subject [Data Structure & Algorithms Lab(PCC-CS301)-SYG]
#
#
# Excellent    73.809524
# Very Good    19.047619
# Good          4.761905
# Very Poor     2.380952
# Name: 1)Instructor’s knowledge about the subject [Data Structure & Algorithms Lab(PCC-CS301)-SYG], dtype: float64
# Analysis on 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Data Structure & Algorithms Lab(PCC-CS301)-SYG]
#
#
# Excellent    76.190476
# Very Good    14.285714
# Good          7.142857
# Very Poor     2.380952
# Name: 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Data Structure & Algorithms Lab(PCC-CS301)-SYG], dtype: float64
# Analysis on 3)Adequacy of time allotted for each experiment of the Course. [Data Structure & Algorithms Lab(PCC-CS301)-SYG]
#
#
# Excellent    78.571429
# Very Good    16.666667
# Very Poor     2.380952
# Good          2.380952
# ...

# %% [markdown]
# ## **Data Structure & Algorithms Lab (PCC-CS301)-AGB**

# %%
index=4
for ind,val in enumerate(titles):
    if ind == 0:
      analysis(titles[index])
    elif index < len(code)-8:
      index=index+8
      analysis(titles[index])
# Out:
# Analysis on 1)Instructor’s knowledge about the subject [Data Structure & Algorithms Lab (PCC-CS301)-AGB]
#
#
# Excellent    50.000000
# Very Good    26.190476
# Good         11.904762
# Poor          7.142857
# Very Poor     4.761905
# Name: 1)Instructor’s knowledge about the subject [Data Structure & Algorithms Lab (PCC-CS301)-AGB], dtype: float64
# Analysis on 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Data Structure & Algorithms Lab (PCC-CS301)-AGB]
#
#
# Excellent    61.904762
# Very Good    16.666667
# Good          9.523810
# Poor          7.142857
# Very Poor     4.761905
# Name: 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Data Structure & Algorithms Lab (PCC-CS301)-AGB], dtype: float64
# Analysis on 3)Adequacy of time allotted for each experiment of the Course. [Data Structure & Algorithms Lab (PCC-CS301)-AGB]
#
#
# Excellent    61.904762
# Very Good    21.428571
# Good          9.523810
# ...

# %% [markdown]
# ## **Computer Organisation Lab(PCC-CS302)-RPC**

# %%
index=5
for ind,val in enumerate(titles):
    if ind == 0:
      analysis(titles[index])
    elif index < len(code)-8:
      index=index+8
      analysis(titles[index])
# Out:
# Analysis on 1)Instructor’s knowledge about the subject [Computer Organisation Lab(PCC-CS302)-RPC]
#
#
# Excellent    83.333333
# Very Good     9.523810
# Good          7.142857
# Name: 1)Instructor’s knowledge about the subject [Computer Organisation Lab(PCC-CS302)-RPC], dtype: float64
# Analysis on 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Computer Organisation Lab(PCC-CS302)-RPC]
#
#
# Excellent    85.714286
# Very Good     9.523810
# Good          4.761905
# Name: 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Computer Organisation Lab(PCC-CS302)-RPC], dtype: float64
# Analysis on 3)Adequacy of time allotted for each experiment of the Course. [Computer Organisation Lab(PCC-CS302)-RPC]
#
#
# Excellent    85.714286
# Very Good    11.904762
# Good          2.380952
# Name: 3)Adequacy of time allotted for each experiment of the Course. [Computer Organisation Lab(PCC-CS302)-RPC], dtype: float64
# ...

# %% [markdown]
# ## **Computer Organisation Lab(PCC-CS302)-SBK**

# %%
index=6
for ind,val in enumerate(titles):
    if ind == 0:
      analysis(titles[index])
    elif index < len(code)-8:
      index=index+8
      analysis(titles[index])
# Out:
# Analysis on 1)Instructor’s knowledge about the subject [Computer Organisation Lab(PCC-CS302)-SBK]
#
#
# Excellent    61.904762
# Very Good    21.428571
# Good         16.666667
# Name: 1)Instructor’s knowledge about the subject [Computer Organisation Lab(PCC-CS302)-SBK], dtype: float64
# Analysis on 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Computer Organisation Lab(PCC-CS302)-SBK]
#
#
# Excellent    66.666667
# Very Good    21.428571
# Good         11.904762
# Name: 2)Instructor's ability to stimulate Problem Solving and intellectual curiosity. [Computer Organisation Lab(PCC-CS302)-SBK], dtype: float64
# Analysis on 3)Adequacy of time allotted for each experiment of the Course. [Computer Organisation Lab(PCC-CS302)-SBK]
#
#
# Excellent    76.190476
# Very Good    19.047619
# Good          4.761905
# Name: 3)Adequacy of time allotted for each experiment of the Course. [Computer Organisation Lab(PCC-CS302)-SBK], dtype: float64
# ...
