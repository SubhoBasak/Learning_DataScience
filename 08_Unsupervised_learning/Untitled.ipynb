# %%
from PIL import Image

# %%
img = Image.open('img.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=286x176 at 0x1B7C2788080>

# %%
width, height = img.size

# %%
img.resize((100, 100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1B7C26C9630>

# %%
height = height*200//width
height
# Out:
# 123

# %%
width = 200

# %%
img.resize((width, height))
# Out:
# <PIL.Image.Image image mode=RGB size=200x123 at 0x1B7C1715A58>

# %%
img.save('new_img.jpg')
