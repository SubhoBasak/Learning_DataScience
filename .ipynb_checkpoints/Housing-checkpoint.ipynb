# %%
import os
import tarfile
import urllib

# %%
url = 'https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.tgz'

# %%
resp = urllib.request.urlopen(url)
with open('housing.tgz', 'wb') as file:
    file.write(resp.read())

# %%
housing_tgz = tarfile.open('housing.tgz')
housing_tgz.extractall()
housing_tgz.close()

# %%
import pandas as pd

# %%
data = pd.read_csv('housing.csv')

# %%
data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('dark_background')

# %%
data.hist(figsize = (10, 7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019942DE62B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019943086400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199430BB9B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000199430EBF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019943128518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019943158AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000199431970B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199431C66A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199431C66D8>]],
#       dtype=object)

# %%
data['total_rooms'].hist(figsize = (10, 6))

# %%
from sklearn.model_selection import train_test_split

# %%
housing_x = data.drop('median_house_value', axis = 1)
housing_y = data.median_house_value

# %%
housing_x.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity'],
#       dtype='object')

# %%
housing_y.name
# Out:
# 'median_house_value'

# %%
x_train, x_test, y_train, y_test = train_test_split(housing_x, housing_y, test_size = 0.3)

# %%
x_train.shape
# Out:
# (14448, 9)

# %%
x_test.shape
# Out:
# (6192, 9)

# %%
y_train.shape
# Out:
# (14448,)

# %%
y_test.shape
# Out:
# (6192,)

# %%
import numpy as np

# %%
data['income_cat'] = pd.cut(data['median_income'],
                           bins = [0.0, 1.5, 3.0, 4.5, 6, np.inf],
                           labels = [1, 2, 3, 4, 5])

data.income_cat.hist(figsize = (10, 7))

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2)

for train_index, test_index in split.split(data, data['income_cat']):
    strat_train_set = data.loc[train_index]
    strat_test_set = data.loc[test_index]

# %%
strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9622     -120.32     37.29                38.0        576.0             NaN
# 19466    -120.97     37.68                16.0       2349.0           446.0
# 8723     -118.37     33.84                35.0       1792.0           322.0
# 10442    -117.59     33.41                17.0       2248.0           448.0
# 17816    -121.84     37.40                25.0       1866.0           271.0
# ...          ...       ...                 ...          ...             ...
# 2596     -124.08     40.91                13.0       2522.0           719.0
# 2835     -118.99     35.40                48.0       1908.0           331.0
# 8033     -118.14     33.84                43.0       2107.0           439.0
# 19293    -122.83     38.40                37.0       2217.0           451.0
# 19484    -120.98     37.65                36.0        826.0           167.0
#
#        population  households  median_income  median_house_value  \
# 9622        478.0       112.0         2.3382             59600.0
# 19466      1302.0       392.0         3.1625            130300.0
# 8723        978.0       326.0         4.9583            342800.0
# 10442       878.0       423.0         5.1298            246000.0
# 17816       840.0       275.0         6.8677            288500.0
# ...           ...         ...            ...                 ...
# 2596       1381.0       628.0         1.6667             78800.0
# 2835        789.0       321.0         3.5714             84600.0
# 8033        876.0       429.0         3.2024            339400.0
# 19293      1019.0       428.0         3.1217            178500.0
# 19484       432.0       150.0         2.5000            103100.0
#
#       ocean_proximity income_cat
# 9622           INLAND          2
# 19466          INLAND          3
# 8723        <1H OCEAN          4
# 10442      NEAR OCEAN          4
# 17816       <1H OCEAN          5
# ...               ...        ...
# 2596       NEAR OCEAN          2
# 2835           INLAND          3
# 8033        <1H OCEAN          3
# 19293       <1H OCEAN          3
# 19484          INLAND          2
#
# [16512 rows x 11 columns]

# %%
strat_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3479     -118.51     34.29                29.0       1287.0           194.0
# 6918     -118.00     33.96                37.0       2414.0           323.0
# 2376     -119.55     36.69                21.0       1551.0           423.0
# 18383    -121.80     37.19                45.0       1797.0           303.0
# 2498     -120.51     36.55                20.0       1193.0           263.0
# ...          ...       ...                 ...          ...             ...
# 17345    -120.43     34.86                17.0       1932.0           347.0
# 3200     -119.65     36.35                38.0       3148.0           568.0
# 4012     -118.60     34.16                37.0       3441.0           584.0
# 9212     -120.35     37.04                37.0       1495.0           292.0
# 8744     -118.32     33.81                27.0       2113.0           380.0
#
#        population  households  median_income  median_house_value  \
# 3479        525.0       187.0         6.4171            319300.0
# 6918        878.0       305.0         9.1541            453800.0
# 2376       1519.0       406.0         1.7132             55900.0
# 18383       870.0       281.0         4.5417            434500.0
# 2498       1274.0       241.0         1.9417             38800.0
# ...           ...         ...            ...                 ...
# 17345       874.0       312.0         3.8203            141500.0
# 3200       1378.0       537.0         2.8788             85500.0
# 4012       1283.0       544.0         4.1656            313100.0
# 9212        858.0       275.0         2.9306             46300.0
# 8744       1109.0       360.0         4.7062            357000.0
#
#       ocean_proximity income_cat
# 3479        <1H OCEAN          5
# 6918        <1H OCEAN          5
# 2376           INLAND          2
# 18383       <1H OCEAN          4
# 2498           INLAND          2
# ...               ...        ...
# 17345       <1H OCEAN          3
# 3200           INLAND          2
# 4012        <1H OCEAN          3
# 9212           INLAND          2
# 8744        <1H OCEAN          4
#
# [4128 rows x 11 columns]

# %%
strat_test_set['income_cat'].value_counts()
# Out:
# 3    1447
# 2    1316
# 4     728
# 5     473
# 1     164
# Name: income_cat, dtype: int64

# %%
strat_train_set['income_cat'].value_counts()
# Out:
# 3    5789
# 2    5265
# 4    2911
# 5    1889
# 1     658
# Name: income_cat, dtype: int64

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop('income_cat', axis = 1, inplace = True)

# %%
strat_test_set.shape
# Out:
# (4128, 10)

# %%
temp = strat_train_set.copy()

# %%
plt.figure(figsize = (10, 7))
plt.scatter(temp['longitude'], temp['latitude'], alpha = 0.1)

# %%
plt.figure(figsize = (10, 7))
plt.scatter(strat_test_set['longitude'], strat_test_set['latitude'], alpha = 0.1)

# %%
plt.figure(figsize = (10, 7))
plt.scatter(temp.longitude, temp.latitude, c = temp.median_house_value,
           s = temp.population/100, cmap = plt.get_cmap('jet'), label = 'population')
plt.legend()
plt.colorbar()

# %%
plt.figure(figsize = (10, 7))
plt.scatter(temp.longitude, temp.latitude, c = temp.median_house_value,
           s = temp.population/100, cmap = plt.get_cmap('jet'), label = 'population')
plt.colorbar()
plt.legend()
plt.grid(True)

# %%
corr_matrix = data.corr() # core-relation coefficient

# %%
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.320451   -0.296244   -0.302916      -0.119034
# total_rooms               0.930380    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907222       0.004834
# households                0.979728    0.907222    1.000000       0.013033
# median_income            -0.007723    0.004834    0.013033       1.000000
# median_house_value        0.049686   -0.024650    0.065843       0.688075
#
#                     median_house_value
# longitude                    -0.045967
# latitude                     -0.144160
# housing_median_age            0.105623
# total_rooms                   0.134153
# total_bedrooms                0.049686
# population                   -0.024650
# households                    0.065843
# median_income                 0.688075
# median_house_value            1.000000

# %%
corr_matrix['median_house_value'].sort_values(ascending = False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ['median_house_value', 'median_income', 'total_rooms',
             'housing_median_age']

scatter_matrix(data[attributes], figsize = (20, 14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000199487A5F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199487793C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199487E0438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199486249E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019948653F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001994868F588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199486C0B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199486FF160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000199486FF198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019948933C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019948972278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199489A3828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000199489D4DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019948A133C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019948A42978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019948A76F28>]],
#       dtype=object)

# %%
data.plot(kind = 'scatter', x = 'median_income',
          y = 'median_house_value', alpha = 0.1)
