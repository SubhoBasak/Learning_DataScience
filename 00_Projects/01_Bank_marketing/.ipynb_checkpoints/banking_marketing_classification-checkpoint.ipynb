# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin

# %%
df = pd.read_csv('bank-additional-full.csv', delimiter = ';')

# %%
df.head(10)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null object
# marital           41188 non-null object
# education         41188 non-null object
# default           41188 non-null object
# housing           41188 non-null object
# loan              41188 non-null object
# contact           41188 non-null object
# month             41188 non-null object
# day_of_week       41188 non-null object
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null object
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null object
# ...

# %%
class MonthEncoder(BaseEstimator, TransformerMixin):
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        X = np.array(X.ravel())
        for i in range(len(X)):
            m = X[i];
            if X[i] == 'jan':
                X[i] = 1
            elif X[i] == 'feb':
                X[i] = 2
            elif X[i] == 'mar':
                X[i] = 3
            elif X[i] == 'apr':
                X[i] = 4
            elif X[i] == 'may':
                X[i] = 5
            elif X[i] == 'jun':
                X[i] = 6
            elif X[i] == 'jul':
                X[i] = 7
            elif X[i] == 'aug':
                X[i] = 8
            elif X[i] == 'sep':
                X[i] = 9
            elif X[i] == 'oct':
                X[i] = 10
            elif X[i] == 'nov':
                X[i] = 11
            elif X[i] == 'dec':
                X[i] = 12
        return X.astype('int32').reshape(-1, 1)

# %%
class DayEncoder(BaseEstimator, TransformerMixin):
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        X = np.array(X.ravel())
        for i in range(len(X)):
            if X[i] == 'sun':
                X[i] = 0
            elif X[i] == 'mon':
                X[i] = 1
            elif X[i] == 'tue':
                X[i] = 2
            elif X[i] == 'wed':
                X[i] = 3
            elif X[i] == 'thu':
                X[i] = 4
            elif X[i] == 'fri':
                X[i] = 5
            elif X[i] == 'sat':
                X[i] = 6

        return X.astype('int32').reshape(-1, 1)

# %%
class EducationEncoder(BaseEstimator, TransformerMixin):
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        X = np.array(X.ravel())
        for i in range(len(X)):
            if X[i] == 'basic.4y':
                X[i] = 1
            elif X[i] == 'basic.6y':
                X[i] = 2
            elif X[i] == 'basic.9y':
                X[i] = 3
            elif X[i] == 'high.school':
                X[i] = 4
            elif X[i] == 'illiterate':
                X[i] = 5
            elif X[i] == 'professional.course':
                X[i] = 6
            elif X[i] == 'university.degree':
                X[i] = 7
            elif X[i] == 'unknown':
                X[i] = 2
        
        return X.astype('int32').reshape(-1, 1)

# %%
df['y'].replace('yes', 1, inplace = True)
df['y'].replace('no', 0, inplace = True)

# %%
month_enc = MonthEncoder()
df['month'] = month_enc.fit_transform(df['month'])

# %%
day_enc = DayEncoder()
df['day_of_week'] = day_enc.fit_transform(df['day_of_week'])

# %%
education_enc = EducationEncoder()
df['education'] = education_enc.fit_transform(df['education'])

# %%
class ThreeWayEncoder(BaseEstimator, TransformerMixin):
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        X = np.array(X.ravel())
        for i in range(len(X)):
            if X[i] == 'no' or X[i] == 'failure':
                X[i] = 0
            elif X[i] == 'yes' or X[i] == 'success':
                X[i] = 1
            elif X[i] == 'unknown' or X[i] == 'nonexistent':
                X[i] = -1
        return X.reshape(-1, 1).astype('int32')

# %%
default_enc = ThreeWayEncoder()
housing_enc = ThreeWayEncoder()
loan_enc = ThreeWayEncoder()
poutcome_enc = ThreeWayEncoder()

df['default'] = default_enc.fit_transform(df['default'])
df['housing'] = housing_enc.fit_transform(df['housing'])
df['loan'] = loan_enc.fit_transform(df['loan'])
df['poutcome'] = poutcome_enc.fit_transform(df['poutcome'])

# %%
# ================== job ==================
job_enc = OneHotEncoder()
job_cat = job_enc.fit_transform(df['job'].values.reshape(-1, 1)).toarray().astype('int32')

job_title = np.array(df['job'].value_counts().index)
job_title.sort()
for i, j in enumerate(job_title):
    df[j] = job_cat[:, i]

# ================== marital ==================
marital_enc = OneHotEncoder()
marital_cat = marital_enc.fit_transform(df[['marital']]).toarray().astype('int32')

marital_title = np.array(df['marital'].value_counts().index)
marital_title.sort()
for i, j in enumerate(marital_title):
    df[j] = marital_cat[:, i]

# ================== contact ==================
contact_enc = OneHotEncoder()
contact_cat = contact_enc.fit_transform(df[['contact']]).toarray().astype('int32')

contact_title = np.array(df['contact'].value_counts().index)
contact_title.sort()
for i, j in enumerate(contact_title):
    df[j] = contact_cat[:, i]

# %%
df.drop('marital', axis = 1, inplace = True)
df.drop('contact', axis = 1, inplace = True)
df.drop('job', axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 35 columns):
# age               41188 non-null int64
# education         41188 non-null int32
# default           41188 non-null int32
# housing           41188 non-null int32
# loan              41188 non-null int32
# month             41188 non-null int32
# day_of_week       41188 non-null int32
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null int32
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null int64
# admin.            41188 non-null int32
# blue-collar       41188 non-null int32
# entrepreneur      41188 non-null int32
# ...

# %%
df.hist(figsize = (10, 7))
plt.tight_layout()

# %%
from pandas.plotting import scatter_matrix

# %%
core_mat = df.corr()
core_mat
# Out:
#                      age  education   default   housing      loan     month  \
# age             1.000000  -0.160441 -0.164910 -0.000987 -0.006048  0.077265
# education      -0.160441   1.000000  0.223133  0.023210  0.014485  0.134828
# default        -0.164910   0.223133  1.000000  0.017429  0.007792  0.084984
# housing        -0.000987   0.023210  0.017429  1.000000  0.228650  0.033748
# loan           -0.006048   0.014485  0.007792  0.228650  1.000000  0.003029
# month           0.077265   0.134828  0.084984  0.033748  0.003029  1.000000
# day_of_week    -0.018486  -0.000195  0.003915 -0.009221  0.000662 -0.006959
# duration       -0.000866  -0.017338  0.011478 -0.004850  0.001987 -0.019302
# campaign        0.004594  -0.000866 -0.033077 -0.009768  0.004908 -0.030635
# pdays          -0.034369  -0.034961 -0.079987 -0.010376 -0.000857 -0.079556
# previous        0.024365   0.026637  0.102630  0.017647 -0.003371  0.063754
# ...

# %%
core_mat['y']
# Out:
# age               0.030399
# education         0.046711
# default           0.099199
# housing           0.011379
# loan             -0.003142
# month             0.037187
# day_of_week       0.010051
# duration          0.405274
# campaign         -0.066357
# pdays            -0.324914
# previous          0.230181
# poutcome          0.270373
# emp.var.rate     -0.298334
# cons.price.idx   -0.136211
# cons.conf.idx     0.054878
# euribor3m        -0.307771
# nr.employed      -0.354678
# y                 1.000000
# admin.            0.031426
# blue-collar      -0.074423
# entrepreneur     -0.016644
# housemaid        -0.006505
# management       -0.000419
# retired           0.092221
# self-employed    -0.004663
# services         -0.032301
# student           0.093955
# technician       -0.006149
# unemployed        0.014752
# unknown           0.005211
# divorced         -0.010608
# married          -0.043398
# single            0.054133
# cellular          0.144773
# ...

# %%
X = df.drop('y', axis = 1)
y = df['y'].copy()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4)

# %%
score_board = {'accuracy': [], 'recall': [], 'precision': [], 'f1': []}

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(max_iter = 2000)
log_reg.fit(X_train, y_train)

log_reg.score(X_test, y_test)
# Out:
# 0.913510560815732

# %%
y_pred = log_reg.predict(X_test)

score = accuracy_score(y_test, y_pred)
score_board['accuracy'].append(score)

score = recall_score(y_test, y_pred)
score_board['recall'].append(score)

score = precision_score(y_test, y_pred)
score_board['precision'].append(score)

score = f1_score(y_test, y_pred)
score_board['f1'].append(score)

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from graphviz import Source

# %%
tree_clf = DecisionTreeClassifier()

# %%
# grid_clf = GridSearchCV(tree_clf,
#                         param_grid = {'max_depth': [8, 9, 10, 11], 'max_leaf_nodes': [19, 20, 21, 22], 'max_features': [32, 32, 34]},
#                         cv = 5,
#                         scoring = 'accuracy')
# grid_clf.fit(X_train, y_train)

# %%
# grid_clf.best_params_

# %%
tree_clf = DecisionTreeClassifier(max_depth = 11, max_features = 34, max_leaf_nodes = 22)
tree_clf.fit(X_train, y_train)

tree_clf.score(X_test, y_test)
# Out:
# 0.9173343044428259

# %%
Source(export_graphviz(tree_clf, out_file = None, rounded = True, class_names = ['0', '1'], filled = True))

# %%
y_pred = tree_clf.predict(X_test)

score = accuracy_score(y_test, y_pred)
score_board['accuracy'].append(score)

score = recall_score(y_test, y_pred)
score_board['recall'].append(score)

score = precision_score(y_test, y_pred)
score_board['precision'].append(score)

score = f1_score(y_test, y_pred)
score_board['f1'].append(score)

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()
X_scale = std_scaler.fit_transform(X_train)

svm_clf = SVC(C = 20, degree = 3)
svm_clf.fit(X_scale, y_train)
# Out:
# SVC(C=20, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
X_scale_test = std_scaler.transform(X_test)

svm_clf.score(X_scale_test, y_test)
# Out:
# 0.9065914056809905

# %%
# grid_clf = GridSearchCV(svm_clf,
#                        param_grid = {'C': [5, 10, 20,], 'degree': [3, 10, 20, 30, 34]},
#                        cv = 3,
#                        scoring = 'accuracy')
# grid_clf.fit(X_train, y_train)

# %%
# grid_clf.best_params_

# %%
y_pred = svm_clf.predict(X_scale_test)

score = accuracy_score(y_test, y_pred)
score_board['accuracy'].append(score)

score = recall_score(y_test, y_pred)
score_board['recall'].append(score)

score = precision_score(y_test, y_pred)
score_board['precision'].append(score)

score = f1_score(y_test, y_pred)
score_board['f1'].append(score)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest_clf = RandomForestClassifier()
forest_clf.fit(X_train, y_train)

forest_clf.score(X_test, y_test)
# Out:
# 0.915574168487497

# %%
# grid_clf = GridSearchCV(
#     forest_clf,
#     cv = 3,
#     scoring = 'accuracy',
#     param_grid = {'n_estimators': [20, 25, 30], 'max_depth': [25, 30, 35], 'max_leaf_nodes': [25, 30, 35]}
# )
# grid_clf.fit(X_train, y_train)

# %%
# grid_clf.best_params_

# %%
forest_clf = RandomForestClassifier(max_depth = 25, max_leaf_nodes = 25, n_estimators = 20)
forest_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=25, max_features='auto',
#                        max_leaf_nodes=25, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
forest_clf.score(X_test, y_test)
# Out:
# 0.906409322651129

# %%
y_pred = forest_clf.predict(X_test)

score = accuracy_score(y_test, y_pred)
score_board['accuracy'].append(score)

score = recall_score(y_test, y_pred)
score_board['recall'].append(score)

score = precision_score(y_test, y_pred)
score_board['precision'].append(score)

score = f1_score(y_test, y_pred)
score_board['f1'].append(score)

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting_clf = VotingClassifier(
    estimators = [('logistic', log_reg), ('d_tree', tree_clf), ('sv_clf', svm_clf), ('forest', forest_clf)],
    voting = 'hard'
)

# %%
voting_clf.fit(X_train, y_train)
voting_clf.score(X_test, y_test)
# Out:
# 0.9084729303228939

# %%
y_pred = voting_clf.predict(X_test)

score = accuracy_score(y_test, y_pred)
score_board['accuracy'].append(score)

score = recall_score(y_test, y_pred)
score_board['recall'].append(score)

score = precision_score(y_test, y_pred)
score_board['precision'].append(score)

score = f1_score(y_test, y_pred)
score_board['f1'].append(score)

# %%
score_df = pd.DataFrame(score_board)
score_df.index = ['Logistic Regression', 'Decision Tree', 'SVM Classifeir', 'Random Forest', 'Voting Classifier']

# %%
score_df
# Out:
#                      accuracy    recall  precision        f1
# Logistic Regression  0.913511  0.421687   0.676032  0.519393
# Decision Tree        0.917334  0.529025   0.658038  0.586521
# SVM Classifeir       0.906591  0.466046   0.601413  0.525147
# Random Forest        0.906409  0.231654   0.752669  0.354271
# Voting Classifier    0.908473  0.265060   0.744615  0.390953
