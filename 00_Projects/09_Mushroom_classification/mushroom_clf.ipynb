# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
col_names = ['edibility', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size',
             'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring',
             'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']

df = pd.read_csv('agaricus-lepiota.data.csv', names = col_names, na_values = '?')
df
# Out:
#      edibility cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            p         x           s         n       t    p               f
# 1            e         x           s         y       t    a               f
# 2            e         b           s         w       t    l               f
# 3            p         x           y         w       t    p               f
# 4            e         x           s         g       f    n               f
# ...        ...       ...         ...       ...     ...  ...             ...
# 8119         e         k           s         n       f    n               a
# 8120         e         x           s         n       f    n               a
# 8121         e         f           s         n       f    n               a
# 8122         p         k           y         n       f    y               f
# 8123         e         x           s         n       f    n               a
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(df)

# %%
for col in list(train_set):
    print(col)
    print('===============================')
    print(train_set[col].value_counts().sort_index(ascending = True))
    print()
# Out:
# edibility
# ...
# e    3132
# p    2961
# Name: edibility, dtype: int64
#
# cap-shape
# ...
# b     334
# c       4
# f    2378
# k     596
# s      26
# x    2755
# Name: cap-shape, dtype: int64
#
# cap-surface
# ...
# f    1696
# g       3
# s    1926
# y    2468
# Name: cap-surface, dtype: int64
#
# cap-color
# ...
# b     125
# c      33
# e    1125
# g    1369
# n    1730
# p     113
# r      11
# u      12
# w     748
# y     827
# Name: cap-color, dtype: int64
#
# bruises
# ...
# f    3548
# t    2545
# Name: bruises, dtype: int64
#
# odor
# ...
# a     305
# c     141
# f    1627
# l     303
# m      25
# n    2617
# p     204
# s     453
# y     418
# Name: odor, dtype: int64
#
# gill-attachment
# ...
# a     164
# f    5929
# Name: gill-attachment, dtype: int64
#
# gill-spacing
# ...
# c    5144
# w     949
# Name: gill-spacing, dtype: int64
#
# gill-size
# ...
# b    4204
# n    1889
# Name: gill-size, dtype: int64
#
# gill-color
# ...
# b    1291
# e      68
# g     572
# h     548
# k     307
# n     775
# o      48
# p    1114
# ...

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6093 entries, 4777 to 6454
# Data columns (total 23 columns):
# edibility                   6093 non-null object
# cap-shape                   6093 non-null object
# cap-surface                 6093 non-null object
# cap-color                   6093 non-null object
# bruises                     6093 non-null object
# odor                        6093 non-null object
# gill-attachment             6093 non-null object
# gill-spacing                6093 non-null object
# gill-size                   6093 non-null object
# gill-color                  6093 non-null object
# stalk-shape                 6093 non-null object
# stalk-root                  4237 non-null object
# stalk-surface-above-ring    6093 non-null object
# stalk-surface-below-ring    6093 non-null object
# stalk-color-above-ring      6093 non-null object
# stalk-color-below-ring      6093 non-null object
# veil-type                   6093 non-null object
# ...

# %%
median_value = {}

for i in train_set['stalk-root']:
    if i not in median_value:
        median_value[i] = 1
    else:
        median_value[i] += 1

# %%
median_value
# Out:
# {nan: 1856, 'b': 2831, 'e': 834, 'r': 152, 'c': 420}

# %%
train_set['stalk-root'].fillna({'stalk-root': list(median_value.keys())[np.argmax(median_value.values)]}, inplace = True)
# Out:
# C:\Users\subho\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6093 entries, 4777 to 6454
# Data columns (total 23 columns):
# edibility                   6093 non-null object
# cap-shape                   6093 non-null object
# cap-surface                 6093 non-null object
# cap-color                   6093 non-null object
# bruises                     6093 non-null object
# odor                        6093 non-null object
# gill-attachment             6093 non-null object
# gill-spacing                6093 non-null object
# gill-size                   6093 non-null object
# gill-color                  6093 non-null object
# stalk-shape                 6093 non-null object
# stalk-root                  4237 non-null object
# stalk-surface-above-ring    6093 non-null object
# stalk-surface-below-ring    6093 non-null object
# stalk-color-above-ring      6093 non-null object
# stalk-color-below-ring      6093 non-null object
# veil-type                   6093 non-null object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col_indx in range(len(train_set)):
    le = LabelEncoder()
    for i, val in enumerate(le.fit_transform(train_set[col])):
        train_set.values[i, col_indx] = val
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-d451491c4576> in <module>
#       2     le = LabelEncoder()
#       3     for i, val in enumerate(le.fit_transform(train_set[col])):
# ----> 4         train_set.values[i, col_indx] = val
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in values(self)
#    5441         """
#    5442         self._consolidate_inplace()
# -> 5443         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    5444
#    5445     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in as_array(self, transpose, items)
#     820             arr = np.asarray(mgr.blocks[0].get_values())
#     821         else:
# --> 822             arr = mgr._interleave()
#     823
#     824         return arr.transpose() if transpose else arr
#
# ...

# %%
train_set.head()

# %%
train_set.hist(figsize = (10, 7))
plt.tight_layout()

# %%
train_set.corr()['edibility'].sort_values(ascending = False)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
X = train_set

splitter = StratiffiedShuffleSplit(test_size = 0.3, n_splits = 5)

for train_index, test_index in splitter.split(X)

# %%
from sklearn.metrics import accuracy_score, recall_score, precisio_score, f1_score, precision_recall_curve, roc_curve
from sklearn.model_selection import cross_val_selection, cross_val_predict, GridSearchCV
